# %%
from my_models import extract_face_sequence
seq = extract_face_sequence("test_video.mp4", T=8)
print("Frames extracted:", len(seq))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from my_models import extract_face_sequence
#       2 seq = extract_face_sequence("test_video.mp4", T=8)
#       3 print("Frames extracted:", len(seq))
#
# ModuleNotFoundError: No module named 'my_models'
